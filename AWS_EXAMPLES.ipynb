# %%
import boto3

# %%
## AWS describe
try:
    ec2obj = boto3.client('ec2')
    response = ec2obj.describe_instances()
    print (response)
# Out:
# {'Reservations': [{'Groups': [], 'Instances': [{'AmiLaunchIndex': 0, 'ImageId': 'ami-80bcd4f8', 'InstanceId': 'i-0f787dd6365309612', 'InstanceType': 't2.medium', 'KeyName': 'rkltest', 'LaunchTime': datetime.datetime(2018, 12, 5, 6, 39, 23, tzinfo=tzutc()), 'Monitoring': {'State': 'disabled'}, 'Placement': {'AvailabilityZone': 'us-west-2c', 'GroupName': '', 'Tenancy': 'default'}, 'PrivateDnsName': 'ip-10-10-12-156.us-west-2.compute.internal', 'PrivateIpAddress': '10.10.12.156', 'ProductCodes': [], 'PublicDnsName': 'ec2-54-190-195-161.us-west-2.compute.amazonaws.com', 'PublicIpAddress': '54.190.195.161', 'State': {'Code': 16, 'Name': 'running'}, 'StateTransitionReason': '', 'SubnetId': 'subnet-8c3438d5', 'VpcId': 'vpc-d7de08b3', 'Architecture': 'x86_64', 'BlockDeviceMappings': [{'DeviceName': '/dev/sda1', 'Ebs': {'AttachTime': datetime.datetime(2018, 6, 5, 19, 7, 12, tzinfo=tzutc()), 'DeleteOnTermination': True, 'Status': 'attached', 'VolumeId': 'vol-0d04d8b946db8f47e'}}], 'ClientToken
# ...
